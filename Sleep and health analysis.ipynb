# %%
##Import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
####read csv file in pd
df=pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration
# 0            1    Male   27     Software Engineer             6.1  \
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category
# 0                   6                       42             6   Overweight  \
# ...

# %%
df.shape
# Out:
# (374, 13)

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep
# count  374.000000  374.000000      374.000000        374.000000  \
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
df.describe(include="object")
# Out:
#        Gender Occupation BMI Category Blood Pressure Sleep Disorder
# count     374        374          374            374            155
# unique      2         11            4             25              2
# top      Male      Nurse       Normal         130/85    Sleep Apnea
# freq      189         73          195             99             78

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
df.corr(numeric_only=True)
# Out:
#                          Person ID       Age  Sleep Duration
# Person ID                 1.000000  0.990516        0.296305  \
# Age                       0.990516  1.000000        0.344709
# Sleep Duration            0.296305  0.344709        1.000000
# Quality of Sleep          0.431612  0.473734        0.883213
# Physical Activity Level   0.149882  0.178993        0.212360
# Stress Level             -0.394287 -0.422344       -0.811023
# Heart Rate               -0.225467 -0.225606       -0.516455
# Daily Steps               0.043844  0.057973       -0.039533
#
#                          Quality of Sleep  Physical Activity Level
# Person ID                        0.431612                 0.149882  \
# Age                              0.473734                 0.178993
# Sleep Duration                   0.883213                 0.212360
# Quality of Sleep                 1.000000                 0.192896
# Physical Activity Level          0.192896                 1.000000
# ...

# %%
corrM=df.corr(numeric_only=True)
sns.heatmap(corrM,annot=True)
plt.show()

# %% [markdown]
# # Individual item analysis

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      189
# Female    185
# Name: count, dtype: int64

# %%
sns.countplot(x="Gender",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df["Occupation"].unique()
# Out:
# array(['Software Engineer', 'Doctor', 'Sales Representative', 'Teacher',
#        'Nurse', 'Engineer', 'Accountant', 'Scientist', 'Lawyer',
#        'Salesperson', 'Manager'], dtype=object)

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,7))
sns.countplot(x="Occupation",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df["BMI Category"].unique()
# Out:
# array(['Overweight', 'Normal', 'Obese', 'Normal Weight'], dtype=object)

# %%
df["BMI Category"].value_counts()
# Out:
# BMI Category
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: count, dtype: int64

# %%
sns.countplot(x="BMI Category",data=df,hue="Gender")
# Out:
# <Axes: xlabel='BMI Category', ylabel='count'>

# %%
df["Sleep Disorder"].unique()
# Out:
# array([nan, 'Sleep Apnea', 'Insomnia'], dtype=object)

# %%
df["Sleep Disorder"].value_counts()
# Out:
# Sleep Disorder
# Sleep Apnea    78
# Insomnia       77
# Name: count, dtype: int64

# %% [markdown]
# # Which Sleep Disorder is harmful for male and which is harmful for female

# %%
sns.countplot(x="Sleep Disorder",data=df,hue="Gender")
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='count'>

# %% [markdown]
# # Which occupation have more BMI

# %%
sns.countplot(x="BMI Category",data=df,hue="Occupation")
# Out:
# <Axes: xlabel='BMI Category', ylabel='count'>

# %% [markdown]
# # here is show stress level vs age relation

# %%
sns.catplot(x="Stress Level",y="Age",kind="bar",col="Gender",data=df)

# %% [markdown]
# # Which occcupation have more sleep duration

# %%
sns.catplot(x="Occupation",y="Sleep Duration",kind="bar",data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Due to decreasing the sleep duration the stress level is high

# %%
sns.relplot(x="Sleep Duration",y="Stress Level",data=df)

# %% [markdown]
# # Sleep Duration for male and female

# %%
plt.figure(figsize=(14,7))
sns.countplot(x="Sleep Duration",data=df,hue="Gender")
plt.show()

# %% [markdown]
# # Sleep duration effect on pressure

# %%
sns.catplot(x="Blood Pressure",y="Sleep Duration",kind="bar",data=df,hue="Gender")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Sleep Duration effect on Heart rate

# %%
sns.catplot(x="Heart Rate",y="Sleep Duration",kind="bar",data=df,hue="Gender")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # is Physical Activity Level effect sleep duration

# %%
sns.barplot(x="Physical Activity Level",y="Sleep Duration",data=df,hue="Gender")
# Out:
# <Axes: xlabel='Physical Activity Level', ylabel='Sleep Duration'>

# %% [markdown]
# # Physical Activity Level effect to decrease BMI

# %%
sns.barplot(x="BMI Category",y="Physical Activity Level",hue="Gender",data=df)
# Out:
# <Axes: xlabel='BMI Category', ylabel='Physical Activity Level'>

# %% [markdown]
# # Quality of sleep can effect BMI

# %%
sns.barplot(x="BMI Category",y="Quality of Sleep",hue="Gender",data=df)
# Out:
# <Axes: xlabel='BMI Category', ylabel='Quality of Sleep'>

# %%
df["Daily Steps"].value_counts()
# Out:
# Daily Steps
# 8000     101
# 6000      68
# 5000      68
# 7000      66
# 10000     36
# 5500       4
# 3000       3
# 3500       3
# 4000       3
# 6800       3
# 4800       2
# 7300       2
# 7500       2
# 4200       2
# 3300       2
# 5600       2
# 5200       2
# 4100       2
# 3700       2
# 6200       1
# Name: count, dtype: int64

# %% [markdown]
# # Daily step can decrease BMI

# %%
sns.barplot(x="BMI Category",y="Daily Steps",hue="Gender",data=df)
# Out:
# <Axes: xlabel='BMI Category', ylabel='Daily Steps'>

# %% [markdown]
# # How much stress level can effect on sleep disorder

# %%
sns.barplot(x="Sleep Disorder",y="Stress Level",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='Stress Level'>

# %%
g=sns.PairGrid(df)
g.map(sns.scatterplot)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration
# 0            1    Male   27     Software Engineer             6.1  \
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category
# 0                   6                       42             6   Overweight  \
# ...

# %%
g=sns.PairGrid(df)
g.map(plt.scatter)

# %%
g=sns.PairGrid(df)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)

# %%
g=sns.PairGrid(df,hue="BMI Category")
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend()

# %%
g=sns.PairGrid(df,hue="BMI Category",vars=["Stress Level","BMI Category"])
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend()
plt.xticks(rotation=90)
plt.yticks(rotation=90)
plt.show()

# %%
df.shape
# Out:
# (374, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
x="Heart Rate"
y="Occupation"
plt.figure(figsize=j)
plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 3
#       1 x="Heart Rate"
#       2 y="Occupation"
# ----> 3 plt.plot(x,y)
#       4 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration
# 0            1    Male   27     Software Engineer             6.1  \
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category
# 0                   6                       42             6   Overweight  \
# ...

# %%
df["High_pressure"]=df["Blood Pressure"].str.split("/").str[0]
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration
# 0            1    Male   27     Software Engineer             6.1  \
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category
# 0                   6                       42             6   Overweight  \
# ...

# %%
df["low_pressure"]=df["Blood Pressure"].str.split("/").str[1]
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration
# 0            1    Male   27     Software Engineer             6.1  \
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category
# 0                   6                       42             6   Overweight  \
# ...

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64

# %%
df["BMI Category"].unique()
# Out:
# array(['Overweight', 'Normal', 'Obese', 'Normal Weight'], dtype=object)

# %%
x= df[(df["BMI Category"] == "Obese") | (df["BMI Category"] == "Overweight")]
x
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration
# 0            1    Male   27     Software Engineer             6.1  \
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# 5            6    Male   28     Software Engineer             5.9
# 6            7    Male   29               Teacher             6.3
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category
# 0                   6                       42             6   Overweight  \
# ...

# %%
x["BMI Category"].unique()
# Out:
# array(['Overweight', 'Obese'], dtype=object)
